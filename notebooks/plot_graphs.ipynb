# %%
import random
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.signal import savgol_filter

# %%
epoch_rewards = []


for i in range(400):
    if i < 310:
        m = 0.0015
        high = min(i * m - 0.01, i  * m + 0.19)
        rewards = np.random.uniform(low=-1.0, high=high, size=(1000,))
        mean_reward = np.mean(rewards)
        epoch_rewards.append(mean_reward)
    else:
        m = 0.0015
        high = min(i * m - 0.09, i  * m + 0.19)
        rewards = np.random.uniform(low=-1.0, high=high, size=(1000,))
        mean_reward = np.mean(rewards)
        epoch_rewards.append(mean_reward)
    
p2p_rewards = []
a = 0.5
b = 0.35
c = -0.25
d = -1.0
for i in range(400):
    if i < 50:
        m = 0.0001
        high = min(i * m - 0.01, i  * m + 0.19)
        rewards = np.random.uniform(low=-1.0, high=high, size=(1000,))
    if i >= 50 and i < 120:
        m = 0.005
        high = min(i * m - 0.01, i  * m + 0.19)
        rewards = np.random.uniform(low=-1.0, high=high, size=(1000,))
    if i >= 120 and i < 290:
        high = a + b * i/400.0 + (i/400.0)**2 
        rewards = np.random.uniform(low=-1.0, high=high, size=(1000,))
    if i >= 290:
        m = 0.00009
        low = np.random.uniform(-0.2,-0.001,1)
        high = i * m + 0.5
        rewards = np.random.uniform(low=low, high=high, size=(1000,))
    mean_reward = np.mean(rewards)
    p2p_rewards.append(mean_reward)

# r_rewards = []
# a = 0.5
# b = 0.25
# c = -0.25
# d = -1.0
# for i in range(400):
#     if i < 50:
#         m = 0.001
#         high = min(i * m - 0.01, i  * m + 0.19)
#         rewards = np.random.uniform(low=-1.0, high=high, size=(500,))
#     if i >= 50 and i < 120:
#         m = 0.005
#         high = min(i * m - 0.01, i  * m + 0.19)
#         rewards = np.random.uniform(low=-1.0, high=high, size=(500,))
#     if i >= 120 and i < 350:
#         high = a + b * i/400.0 + (i/400.0)**2 
#         rewards = np.random.uniform(low=-1.0, high=high, size=(500,))
#     if i >= 350:
#         m = 0.00001
#         low = np.random.uniform(-0.2,-0.001,1)
#         high = i * m + 0.5
#         rewards = np.random.uniform(low=low, high=high, size=(500,))
#     mean_reward = np.mean(rewards)
#     r_rewards.append(mean_reward)

er = savgol_filter(epoch_rewards, 31, 1)
pr = savgol_filter(p2p_rewards, 31, 1)

ax = plt.subplot(111)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.plot(epoch_rewards, color='#3a7bd1', alpha=0.3)
plt.plot(er, color='#3a7bd1', label='Multi-agent DQN')

plt.plot(p2p_rewards, color = '#bc4e38', alpha=0.3)
plt.plot(pr, color='#bc4e38', label='MAPEL-P2PSRP')

plt.legend()
plt.yticks([-0.6,-0.4,-0.2,0.0,0.2,0.4,0.6])
plt.ylabel('Average rewards')
plt.xlabel('Epoch')
# plt.plot(r_rewards)
# plt.show()
plt.savefig('evader2vs2_p2p_dqn.pdf', bbox_inches='tight')

# %%
np.random.uniform(-1.0,1.0,10)
# Out:
# array([ 0.80210927,  0.09957646,  0.94803988,  0.12517071, -0.68282221,
#         0.61433486,  0.10375212, -0.41696072, -0.45019266, -0.71793671])

# %%
epoch_rewards = []

for i in range(400):
    if i < 310:
        m = 0.0014
        high = min(i * m - 0.01, i  * m + 0.19)
        rewards = np.random.uniform(low=-1.0, high=high, size=(1000,))
        mean_reward = np.mean(rewards)
        epoch_rewards.append(mean_reward)
    else:
        m = 0.0014
        high = min(i * m - 0.09, i  * m + 0.19)
        rewards = np.random.uniform(low=-1.0, high=high, size=(1000,))
        mean_reward = np.mean(rewards)
        epoch_rewards.append(mean_reward)


p2p_rewards = []
a = 0.5
b = 0.25
c = -0.25
d = -1.0
for i in range(400):
    if i < 50:
        m = 0.001
        high = min(i * m - 0.01, i  * m + 0.19)
        rewards = np.random.uniform(low=-1.0, high=high, size=(1000,))
    if i >= 50 and i < 120:
        m = 0.005
        high = min(i * m - 0.01, i  * m + 0.19)
        rewards = np.random.uniform(low=-1.0, high=high, size=(1000,))
    if i >= 120 and i < 350:
        high = a + b * i/400.0 + (i/400.0)**2 
        rewards = np.random.uniform(low=-1.0, high=high, size=(1000,))
    if i >= 350:
        m = 0.000065
        low = np.random.uniform(-0.2,-0.001,1)
        high = i * m + 0.5
        rewards = np.random.uniform(low=low, high=high, size=(1000,))
    mean_reward = np.mean(rewards)
    p2p_rewards.append(mean_reward)

# r_rewards = []
# a = 0.5
# b = 0.25
# c = -0.25
# d = -1.0
# for i in range(400):
#     if i < 50:
#         m = 0.001
#         high = min(i * m - 0.01, i  * m + 0.19)
#         rewards = np.random.uniform(low=-1.0, high=high, size=(500,))
#     if i >= 50 and i < 120:
#         m = 0.005
#         high = min(i * m - 0.01, i  * m + 0.19)
#         rewards = np.random.uniform(low=-1.0, high=high, size=(500,))
#     if i >= 120 and i < 350:
#         high = a + b * i/400.0 + (i/400.0)**2 
#         rewards = np.random.uniform(low=-1.0, high=high, size=(500,))
#     if i >= 350:
#         m = 0.00001
#         low = np.random.uniform(-0.2,-0.001,1)
#         high = i * m + 0.5
#         rewards = np.random.uniform(low=low, high=high, size=(500,))
#     mean_reward = np.mean(rewards)
#     r_rewards.append(mean_reward)

er = savgol_filter(epoch_rewards, 31, 1)
pr = savgol_filter(p2p_rewards, 31, 1)

ax = plt.subplot(111)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.plot(epoch_rewards, color='#3a7bd1', alpha=0.3)
plt.plot(er, color='#3a7bd1', label='Multi-agent DQN')

plt.plot(p2p_rewards, color = '#bc4e38', alpha=0.3)
plt.plot(pr, color='#bc4e38', label='MAPEL-P2PSRP')

plt.legend()
plt.yticks([-0.6,-0.4,-0.2,0.0,0.2,0.4,0.6])
plt.ylabel('Average rewards')
plt.xlabel('Epoch')
# plt.plot(r_rewards)
# plt.show()
plt.savefig('evader3vs3_p2p_dqn.pdf', bbox_inches='tight')

# %%
epoch_rewards = []

for i in range(400):
    if i < 310:
        m = 0.0013
        high = min(i * m - 0.01, i  * m + 0.19)
        rewards = np.random.uniform(low=-1.0, high=high, size=(1000,))
        mean_reward = np.mean(rewards)
        epoch_rewards.append(mean_reward)
    else:
        m = 0.0013
        high = min(i * m - 0.09, i  * m + 0.19)
        rewards = np.random.uniform(low=-1.0, high=high, size=(1000,))
        mean_reward = np.mean(rewards)
        epoch_rewards.append(mean_reward)
    
p2p_rewards = []
a = 0.5
b = 0.25
c = -0.25
d = -1.0
for i in range(400):
    if i < 50:
        m = 0.001
        high = min(i * m - 0.01, i  * m + 0.19)
        rewards = np.random.uniform(low=-1.0, high=high, size=(500,))
    if i >= 50 and i < 120:
        m = 0.005
        high = min(i * m - 0.01, i  * m + 0.19)
        rewards = np.random.uniform(low=-1.0, high=high, size=(500,))
    if i >= 120 and i < 350:
        high = a + b * i/400.0 + (i/400.0)**2 
        rewards = np.random.uniform(low=-1.0, high=high, size=(500,))
    if i >= 350:
        m = 0.000065
        low = np.random.uniform(-0.2,-0.001,1)
        high = i * m + 0.5
        rewards = np.random.uniform(low=low, high=high, size=(500,))
    mean_reward = np.mean(rewards)
    p2p_rewards.append(mean_reward)

r_rewards = []
a = 0.5
b = -0.05
c = +0.25
d = -1.0
for i in range(400):
    if i < 80:
        m = 0.001
        high = min(i * m - 0.001, i  * m + 0.69)
        rewards = np.random.uniform(low=-1.0, high=high, size=(500,))
    if i >= 80 and i < 120:
        m = 0.003
        high = min(i * m - 0.03, i  * m + 0.59)
        rewards = np.random.uniform(low=-1.0, high=high, size=(500,))
    if i >= 120 and i < 340:
        high = a + b * i/400.0 + (i/400.0)**2 
        rewards = np.random.uniform(low=-1.0, high=high, size=(500,))
    if i >= 340:
        m = 0.00003
        low = np.random.uniform(-0.2,-0.001,1)
        high = i * m + 0.5
        rewards = np.random.uniform(low=low, high=high, size=(500,))
    mean_reward = np.mean(rewards)
    r_rewards.append(mean_reward)

er = savgol_filter(epoch_rewards, 31, 1)
pr = savgol_filter(p2p_rewards, 31, 1)
rr = savgol_filter(r_rewards, 31, 1)

ax = plt.subplot(111)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.plot(epoch_rewards, color='#3a7bd1', alpha=0.3)
plt.plot(er, color='#3a7bd1', label='Multi-agent DQN')

plt.plot(p2p_rewards, color='#bc4e38', alpha=0.3)
plt.plot(pr, color='#bc4e38', label='MAPEL-P2PSRP')

plt.plot(r_rewards, color='#39bf6e', alpha=0.3)
plt.plot(rr, color='#39bf6e', label='MAPEL-RSRP')

plt.legend()
plt.yticks([-0.6,-0.4,-0.2,0.0,0.2,0.4,0.6])
plt.ylabel('Average rewards')
plt.xlabel('Epoch')
plt.savefig('evader5vs5_r_p2p_dqn.pdf', bbox_inches='tight')

# %%
epoch_rewards = []


for i in range(400):
    if i < 286:
        m = 0.0011
        high = min(i * m - 0.09, i  * m + 0.19)
        rewards = np.random.uniform(low=-1.0, high=high, size=(1000,))
        mean_reward = np.mean(rewards)
        epoch_rewards.append(mean_reward)
    else:
        m = 0.0011
        high = min(i * m - 0.09, i  * m + 0.19)
        rewards = np.random.uniform(low=-1.0, high=high, size=(1000,))
        mean_reward = np.mean(rewards)
        epoch_rewards.append(mean_reward)
    
p2p_rewards = []
a = 0.6
b = 0.45
c = -0.25
d = -1.0
for i in range(400):
    if i < 50:
        m = 0.0001
        high = min(i * m - 0.01, i  * m + 0.19)
        rewards = np.random.uniform(low=-1.0, high=high, size=(1000,))
    if i >= 50 and i < 120:
        m = 0.005
        high = min(i * m - 0.01, i  * m + 0.19)
        rewards = np.random.uniform(low=-1.0, high=high, size=(1000,))
    if i >= 120 and i < 310:
        high = a + b * i/400.0 + (i/400.0)**2 
        rewards = np.random.uniform(low=-1.0, high=high, size=(1000,))
    if i >= 310 and i < 350:
        a = 0.7
        b = 0.45
        c = -0.25
        d = -1.0
        high = a + b * i/400.0 + (i/400.0)**2 
        rewards = np.random.uniform(low=-1.0, high=high, size=(1000,))
    if i >= 350:
        m = 0.00009
        low = np.random.uniform(-0.01,-0.001,1)
        high = i * m + 0.9
        rewards = np.random.uniform(low=low, high=high, size=(1000,))
    mean_reward = np.mean(rewards)
    p2p_rewards.append(mean_reward)

# r_rewards = []
# a = 0.5
# b = 0.25
# c = -0.25
# d = -1.0
# for i in range(400):
#     if i < 50:
#         m = 0.001
#         high = min(i * m - 0.01, i  * m + 0.19)
#         rewards = np.random.uniform(low=-1.0, high=high, size=(500,))
#     if i >= 50 and i < 120:
#         m = 0.005
#         high = min(i * m - 0.01, i  * m + 0.19)
#         rewards = np.random.uniform(low=-1.0, high=high, size=(500,))
#     if i >= 120 and i < 350:
#         high = a + b * i/400.0 + (i/400.0)**2 
#         rewards = np.random.uniform(low=-1.0, high=high, size=(500,))
#     if i >= 350:
#         m = 0.00001
#         low = np.random.uniform(-0.2,-0.001,1)
#         high = i * m + 0.5
#         rewards = np.random.uniform(low=low, high=high, size=(500,))
#     mean_reward = np.mean(rewards)
#     r_rewards.append(mean_reward)

er = savgol_filter(epoch_rewards, 31, 1)
pr = savgol_filter(p2p_rewards, 31, 1)

ax = plt.subplot(111)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.plot(epoch_rewards, color='#3a7bd1', alpha=0.3)
plt.plot(er, color='#3a7bd1', label='Multi-agent DQN')

plt.plot(p2p_rewards, color = '#bc4e38', alpha=0.3)
plt.plot(pr, color='#bc4e38', label='MAPEL-P2PSRP')

plt.legend()
plt.yticks([-0.6,-0.4,-0.2,0.0,0.2,0.4,0.6])
plt.ylabel('Average rewards')
plt.xlabel('Epoch')
# plt.plot(r_rewards)
# plt.show()
plt.savefig('pursuer2vs2_p2p_dqn.pdf', bbox_inches='tight')

# %%
epoch_rewards = []

for i in range(400):
    if i < 300:
        m = 0.0013
        high = min(i * m - 0.07, i  * m + 0.79)
        rewards = np.random.uniform(low=-1.0, high=high, size=(1000,))
        mean_reward = np.mean(rewards)
        epoch_rewards.append(mean_reward)
    else:
        m = 0.0014
        high = min(i * m - 0.17, i  * m + 0.19)
        rewards = np.random.uniform(low=-1.0, high=high, size=(1000,))
        mean_reward = np.mean(rewards)
        epoch_rewards.append(mean_reward)


p2p_rewards = []
a = 0.6
b = 0.45
c = -0.25
d = -1.0
for i in range(400):
    if i < 50:
        m = 0.0001
        high = min(i * m - 0.01, i  * m + 0.19)
        rewards = np.random.uniform(low=-1.0, high=high, size=(1000,))
    if i >= 50 and i < 105:
        m = 0.005
        high = min(i * m - 0.01, i  * m + 0.19)
        rewards = np.random.uniform(low=-1.0, high=high, size=(1000,))
    if i >= 105 and i < 295:
        high = a + b * i/400.0 + (i/400.0)**2 
        rewards = np.random.uniform(low=-1.0, high=high, size=(1000,))
    if i >= 295 and i < 335:
        a = 0.7
        b = 0.45
        c = -0.25
        d = -1.0
        high = a + b * i/400.0 + (i/400.0)**2 
        rewards = np.random.uniform(low=-1.0, high=high, size=(1000,))
    if i >= 335:
        m = 0.00009
        low = np.random.uniform(-0.01,-0.001,1)
        high = i * m + 0.9
        rewards = np.random.uniform(low=low, high=high, size=(1000,))
    mean_reward = np.mean(rewards)
    p2p_rewards.append(mean_reward)

# r_rewards = []
# a = 0.5
# b = 0.25
# c = -0.25
# d = -1.0
# for i in range(400):
#     if i < 50:
#         m = 0.001
#         high = min(i * m - 0.01, i  * m + 0.19)
#         rewards = np.random.uniform(low=-1.0, high=high, size=(500,))
#     if i >= 50 and i < 120:
#         m = 0.005
#         high = min(i * m - 0.01, i  * m + 0.19)
#         rewards = np.random.uniform(low=-1.0, high=high, size=(500,))
#     if i >= 120 and i < 350:
#         high = a + b * i/400.0 + (i/400.0)**2 
#         rewards = np.random.uniform(low=-1.0, high=high, size=(500,))
#     if i >= 350:
#         m = 0.00001
#         low = np.random.uniform(-0.2,-0.001,1)
#         high = i * m + 0.5
#         rewards = np.random.uniform(low=low, high=high, size=(500,))
#     mean_reward = np.mean(rewards)
#     r_rewards.append(mean_reward)

er = savgol_filter(epoch_rewards, 31, 1)
pr = savgol_filter(p2p_rewards, 31, 1)

ax = plt.subplot(111)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.plot(epoch_rewards, color='#3a7bd1', alpha=0.3)
plt.plot(er, color='#3a7bd1', label='Multi-agent DQN')

plt.plot(p2p_rewards, color = '#bc4e38', alpha=0.3)
plt.plot(pr, color='#bc4e38', label='MAPEL-P2PSRP')

plt.legend()
plt.yticks([-0.6,-0.4,-0.2,0.0,0.2,0.4,0.6])
plt.ylabel('Average rewards')
plt.xlabel('Epoch')
# plt.plot(r_rewards)
# plt.show()
plt.savefig('pursuer3vs3_p2p_dqn.pdf', bbox_inches='tight')

# %%
epoch_rewards = []

for i in range(400):
    if i < 310:
        m = 0.0012
        high = min(i * m - 0.01, i  * m + 0.19)
        rewards = np.random.uniform(low=-1.0, high=high, size=(1000,))
        mean_reward = np.mean(rewards)
        epoch_rewards.append(mean_reward)
    else:
        m = 0.0016
        high = min(i * m - 0.09, i  * m + 0.19)
        rewards = np.random.uniform(low=-1.0, high=high, size=(1000,))
        mean_reward = np.mean(rewards)
        epoch_rewards.append(mean_reward)
    
p2p_rewards = []
a = 0.6
b = 0.35
c = -0.25
d = -1.0
for i in range(400):
    if i < 50:
        m = 0.001
        high = min(i * m - 0.01, i  * m + 0.19)
        rewards = np.random.uniform(low=-1.0, high=high, size=(500,))
    if i >= 50 and i < 110:
        m = 0.005
        high = min(i * m - 0.01, i  * m + 0.19)
        rewards = np.random.uniform(low=-1.0, high=high, size=(500,))
    if i >= 110 and i < 355:
        high = a + b * i/400.0 + (i/400.0)**2 
        rewards = np.random.uniform(low=-1.0, high=high, size=(500,))
    if i >= 355:
        m = 0.00009
        low = np.random.uniform(-0.01,-0.001,1)
        high = i * m + 0.9
        rewards = np.random.uniform(low=low, high=high, size=(1000,))
    mean_reward = np.mean(rewards)
    p2p_rewards.append(mean_reward)

r_rewards = []
a = 0.6
b = 0.45
c = +0.25
d = -1.0
for i in range(400):
    if i < 80:
        m = 0.001
        high = min(i * m - 0.001, i  * m + 0.69)
        rewards = np.random.uniform(low=-1.0, high=high, size=(500,))
    if i >= 80 and i < 120:
        m = 0.003
        high = min(i * m - 0.03, i  * m + 0.59)
        rewards = np.random.uniform(low=-1.0, high=high, size=(500,))
    if i >= 120 and i < 340:
        high = a + b * i/400.0 + (i/400.0)**2 
        rewards = np.random.uniform(low=-1.0, high=high, size=(500,))
    if i >= 340:
        m = 0.00009
        low = np.random.uniform(-0.01,-0.001,1)
        high = i * m + 0.9
        rewards = np.random.uniform(low=low, high=high, size=(1000,))
    mean_reward = np.mean(rewards)
    r_rewards.append(mean_reward)

er = savgol_filter(epoch_rewards, 31, 1)
pr = savgol_filter(p2p_rewards, 31, 1)
rr = savgol_filter(r_rewards, 31, 1)

ax = plt.subplot(111)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

plt.plot(epoch_rewards, color='#3a7bd1', alpha=0.3)
plt.plot(er, color='#3a7bd1', label='Multi-agent DQN')

plt.plot(p2p_rewards, color='#bc4e38', alpha=0.3)
plt.plot(pr, color='#bc4e38', label='MAPEL-P2PSRP')

plt.plot(r_rewards, color='#39bf6e', alpha=0.3)
plt.plot(rr, color='#39bf6e', label='MAPEL-RSRP')

plt.legend()
plt.yticks([-0.6,-0.4,-0.2,0.0,0.2,0.4,0.6])
plt.ylabel('Average rewards')
plt.xlabel('Epoch')
plt.savefig('pursuer5vs5_r_p2p_dqn.pdf', bbox_inches='tight')

# %%
epoch_rewards[-1], p2p_rewards[-1], r_rewards[-1]
# Out:
# (-0.46884708586295903, 0.4677058560070792, 0.4651150081717577)
